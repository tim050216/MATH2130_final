# %% [markdown]
# ## RQ1: Can the next pitch type thrown by a Blue Jays pitcher be predicted using pitch context and game state?

# %%
# Import necessary libraries and suppress warnings
import warnings
warnings.filterwarnings('ignore')

import pandas                  as pd
import numpy                   as np
import matplotlib.pyplot       as plt
import seaborn                 as sns
import statsmodels.api         as sm
import statsmodels.formula.api as smf
from sklearn import tree
from sklearn import metrics
from sklearn import neighbors
from sklearn import ensemble
# This statement allow to display plot without asking to 
# %matplotlib inline

# always make it pretty 
plt.style.use('ggplot')

# %%
# %store -r bj_df

# Sorts dataframe in a chronological order for lag features
# Sort by game_pk - pitches from game 1, game 2,..
# Sort by at_bat_number - pitches at-bat 1, at-bat 2,..
# Sort by pitch_number - pitches from each at-bat
sorted_bj = bj_df.sort_values(by=['game_pk', 'at_bat_number', 'pitch_number'])

sorted_bj
# Out:
#        game_year   game_date     player_name  pitcher  batter  balls  strikes  \
# 13339       2025  2025-10-29  Yesavage, Trey   702056  660271      0        0
# 13340       2025  2025-10-29  Yesavage, Trey   702056  660271      1        0
# 13341       2025  2025-10-29  Yesavage, Trey   702056  660271      1        1
# 13342       2025  2025-10-29  Yesavage, Trey   702056  660271      1        2
# 13343       2025  2025-10-29  Yesavage, Trey   702056  660271      2        2
# ...          ...         ...             ...      ...     ...    ...      ...
# 3626        2025  2025-10-04   Hoffman, Jeff   656546  683011      0        0
# 3627        2025  2025-10-04   Hoffman, Jeff   656546  683011      0        1
# 3628        2025  2025-10-04   Hoffman, Jeff   656546  683011      0        2
# 3629        2025  2025-10-04   Hoffman, Jeff   656546  683011      1        2
# 3630        2025  2025-10-04   Hoffman, Jeff   656546  683011      2        2
#
#        inning inning_topbot  at_bat_number  ...  post_home_score  \
# 13339       1           Bot              7  ...                0
# 13340       1           Bot              7  ...                0
# 13341       1           Bot              7  ...                0
# 13342       1           Bot              7  ...                0
# 13343       1           Bot              7  ...                0
# ...       ...           ...            ...  ...              ...
# 3626        9           Top             75  ...               10
# 3627        9           Top             75  ...               10
# 3628        9           Top             75  ...               10
# 3629        9           Top             75  ...               10
# 3630        9           Top             75  ...               10
#
#       post_bat_score post_fld_score if_fielding_alignment  \
# 13339              0              2         Infield shade
# 13340              0              2         Infield shade
# 13341              0              2         Infield shade
# 13342              0              2         Infield shade
# 13343              0              2         Infield shade
# ...              ...            ...                   ...
# 3626               1             10              Standard
# 3627               1             10              Standard
# 3628               1             10              Standard
# 3629               1             10              Standard
# 3630               1             10              Standard
#
#        of_fielding_alignment  spin_axis  delta_home_win_exp delta_run_exp  \
# 13339               Standard      196.0               0.000         0.041
# 13340               Standard      215.0               0.000        -0.050
# 13341               Standard      203.0               0.000        -0.061
# 13342               Standard      219.0               0.000         0.043
# 13343               Standard      210.0               0.000         0.000
# ...                      ...        ...                 ...           ...
# 3626                Standard      224.0               0.000        -0.042
# 3627                Standard      218.0               0.000        -0.056
# 3628                Standard      217.0               0.000         0.015
# 3629                Standard      224.0               0.000         0.012
# 3630                Standard      240.0               0.001        -0.220
#
#        bat_speed swing_length
# 13339        NaN          NaN
# 13340        NaN          NaN
# 13341       82.9          8.7
# 13342        NaN          NaN
# 13343       78.4          7.3
# ...          ...          ...
# 3626         NaN          NaN
# 3627        75.7          6.9
# 3628         NaN          NaN
# 3629         NaN          NaN
# 3630        75.7          8.3
#
# [2788 rows x 87 columns]
